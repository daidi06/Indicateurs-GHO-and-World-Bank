# %%
from urllib.request import urlopen
import json
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Retrieving the list of available dimensions

# %%
response = urlopen("https://ghoapi.azureedge.net/api/Dimension")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
dimGHO = pd.json_normalize(d['value'])
dimGHO.head(15)
# Out:
#                      Code                                     Title
# 0         ADVERTISINGTYPE         SUBSTANCE_ABUSE_ADVERTISING_TYPES
# 1                AGEGROUP                                 Age Group
# 2             ALCOHOLTYPE                            Beverage Types
# 3        AMRGLASSCATEGORY                        AMR GLASS Category
# 4                 ARCHIVE                              Archive date
# 5   AWARENESSACTIVITYTYPE  SUBSTANCE_ABUSE_AWARENESS_ACTIVITY_TYPES
# 6                BACGROUP                SUBSTANCE_ABUSE_BAC_GROUPS
# 7            BEVERAGETYPE            SUBSTANCE_ABUSE_BEVERAGE_TYPES
# 8             CAREPATIENT                              Patient type
# 9              CARESECTOR                               Care sector
# 10             CHILDCAUSE                            Cause of death
# 11    COMMUNITYACTIONTYPE                          Community Action
# 12        CONSUMPTIONTYPE                          Consumption type
# 13   COORDINATINGENTITIES     SUBSTANCE_ABUSE_COORDINATING_ENTITIES
# 14                COUNTRY                                   Country

# %% [markdown]
# # Retrieving a list of available values for a specific dimension

# %% [markdown]
# ## Retrieve the list of the `COUNTRY` dimension values

# %%
response = urlopen("https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
df_Code = pd.json_normalize(d['value'])
df_Code.head(15)
# Out:
#       Code                 Title ParentDimension Dimension ParentCode  \
# 0      ABW                 Aruba          REGION   COUNTRY        AMR
# 1      AFG           Afghanistan          REGION   COUNTRY        EMR
# 2      AGO                Angola          REGION   COUNTRY        AFR
# 3      AIA              Anguilla          REGION   COUNTRY        AMR
# 4      ALB               Albania          REGION   COUNTRY        EUR
# 5      AND               Andorra          REGION   COUNTRY        EUR
# 6   ANT530       SPATIAL_SYNONYM          REGION   COUNTRY        AMR
# 7   ANT532       SPATIAL_SYNONYM          REGION   COUNTRY        AMR
# 8      ARE  United Arab Emirates          REGION   COUNTRY        EMR
# 9      ARG             Argentina          REGION   COUNTRY        AMR
# 10     ARM               Armenia          REGION   COUNTRY        EUR
# 11     ASM        American Samoa          REGION   COUNTRY        WPR
# 12     ATG   Antigua and Barbuda          REGION   COUNTRY        AMR
# 13     AUS             Australia          REGION   COUNTRY        WPR
# 14     AUT               Austria          REGION   COUNTRY        EUR
#
#               ParentTitle
# 0                Americas
# 1   Eastern Mediterranean
# 2                  Africa
# 3                Americas
# 4                  Europe
# 5                  Europe
# 6                Americas
# 7                Americas
# 8   Eastern Mediterranean
# 9                Americas
# 10                 Europe
# 11        Western Pacific
# 12               Americas
# 13        Western Pacific
# 14                 Europe

# %% [markdown]
# ## Filter Africa Region

# %%
df_Code_afro = df_Code[df_Code.ParentCode=="AFR"]
df_Code_afro.head(10)
# Out:
#   Code                     Title ParentDimension Dimension ParentCode  \
# 0  AGO                    Angola          REGION   COUNTRY        AFR
# 1  BDI                   Burundi          REGION   COUNTRY        AFR
# 2  BEN                     Benin          REGION   COUNTRY        AFR
# 3  BFA              Burkina Faso          REGION   COUNTRY        AFR
# 4  BWA                  Botswana          REGION   COUNTRY        AFR
# 5  CAF  Central African Republic          REGION   COUNTRY        AFR
# 6  ZMB                    Zambia          REGION   COUNTRY        AFR
# 7  ZWE                  Zimbabwe          REGION   COUNTRY        AFR
# 8  SYC                Seychelles          REGION   COUNTRY        AFR
# 9  TCD                      Chad          REGION   COUNTRY        AFR
#
#   ParentTitle
# 0      Africa
# 1      Africa
# 2      Africa
# 3      Africa
# 4      Africa
# 5      Africa
# 6      Africa
# 7      Africa
# 8      Africa
# 9      Africa

# %%
df_Code_afro.shape
# Out:
# (50, 6)

# %%
df_Code_afro.Title.unique()
# Out:
# array(['Angola', 'Burundi', 'Benin', 'Burkina Faso', 'Botswana',
#        'Central African Republic', 'Zambia', 'Zimbabwe', 'Seychelles',
#        'Chad', 'Togo', 'United Republic of Tanzania', 'Uganda',
#        'South Africa', 'Senegal', 'Saint Helena', 'Sierra Leone',
#        'South Sudan', 'Sao Tome and Principe', 'Eswatini', 'Mayotte',
#        'Namibia', 'Niger', 'Nigeria', 'Reunion', 'Rwanda', 'Madagascar',
#        'Mali', 'Mozambique', 'Mauritania', 'Mauritius', 'Malawi',
#        'Gambia', 'Guinea-Bissau', 'Equatorial Guinea', 'Kenya', 'Liberia',
#        'Lesotho', 'Algeria', 'Eritrea', 'Ethiopia', 'Gabon', 'Ghana',
#        'Guinea', "Côte d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Congo', 'Comoros',
#        'Cabo Verde'], dtype=object)

# %% [markdown]
# # Retrieving the list of all the indicators in GHO with their code

# %%
response = urlopen("https://ghoapi.azureedge.net/api/Indicator")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
df_Indicators = pd.json_normalize(d['value'])
df_Indicators.head(15)
# Out:
#    IndicatorCode                                      IndicatorName Language
# 0         AIR_10  Ambient air pollution  attributable DALYs per ...       EN
# 1         AIR_11        Household air pollution attributable deaths       EN
# 2         AIR_12  Household air pollution attributable deaths in...       EN
# 3         AIR_13  Household air pollution attributable deaths pe...       EN
# 4         AIR_14  Household air pollution  attributable deaths p...       EN
# 5         AIR_15         Household air pollution attributable DALYs       EN
# 6         AIR_16  Household air pollution attributable DALYs in ...       EN
# 7         AIR_17  Household air pollution attributable DALYs (pe...       EN
# 8         AIR_18  Household air pollution  attributable DALYs pe...       EN
# 9         AIR_39  Household air pollution attributable DALYs (pe...       EN
# 10         AIR_4  Ambient air pollution attributable deaths in c...       EN
# 11        AIR_41          Ambient air pollution attributable deaths       EN
# 12        AIR_42  Ambient air pollution attributable death rate ...       EN
# 13        AIR_43           Ambient air pollution attributable DALYs       EN
# 14        AIR_44  DALYs attributable to ambient air pollution (a...       EN

# %%
df_Indicators[df_Indicators['IndicatorCode']=='cpmo']
# Out:
#    IndicatorCode                                  IndicatorName Language
# 80          cpmo  Contraceptive prevalence - modern methods (%)       EN

# %%
 df_Indicators[df_Indicators['IndicatorCode']=='cpmt']
# Out:
#    IndicatorCode                                      IndicatorName Language
# 81          cpmt  Contraceptive prevalence - modern and traditio...       EN

# %%
df_Indicators.shape
# Out:
# (2247, 3)

# %% [markdown]
# # List of all the indicators in GHO containing the word 'Household'

# %%
response = urlopen("https://ghoapi.azureedge.net/api/Indicator?$filter=contains(IndicatorName,'Household')")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
df_Indicators2 = pd.json_normalize(d['value'])
df_Indicators2
# Out:
#                               IndicatorCode  \
# 0                                    AIR_11
# 1                                    AIR_12
# 2                                    AIR_13
# 3                                    AIR_14
# 4                                    AIR_15
# 5                                    AIR_16
# 6                                    AIR_17
# 7                                    AIR_18
# 8                                    AIR_39
# 9                                    AIR_51
# 10                                   AIR_52
# 11  FINPROTECTION_CATA_TOT_10_LEVEL_MILLION
# 12       FINPROTECTION_CATA_TOT_10_LEVEL_SH
# 13            FINPROTECTION_CATA_TOT_10_POP
# 14  FINPROTECTION_CATA_TOT_25_LEVEL_MILLION
# 15       FINPROTECTION_CATA_TOT_25_LEVEL_SH
# 16            FINPROTECTION_CATA_TOT_25_POP
# 17   FINPROTECTION_IMP_NP_190_LEVEL_MILLION
# 18        FINPROTECTION_IMP_NP_190_LEVEL_SH
# 19   FINPROTECTION_IMP_NP_310_LEVEL_MILLION
# 20        FINPROTECTION_IMP_NP_310_LEVEL_SH
# 21              FINPROTECTION_IMP_NP190_POP
# 22              FINPROTECTION_IMP_NP310_POP
# 23                 FINPROTECTION_IMP_PG_190
# 24             FINPROTECTION_IMP_PG_190_STD
# 25                 FINPROTECTION_IMP_PG_310
# 26             FINPROTECTION_IMP_PG_310_STD
# 27                            GDO_q16x1x1_2
# 28                            MALARIA_15136
# 29                            MALARIA_15137
# 30                            MALARIA_30515
# 31                            MALARIA_30516
# 32                            MALARIA_30517
# 33                            MALARIA_30518
# 34                            MALARIA_30519
# 35                            MALARIA_30521
# 36                            MALARIA_30522
# 37                  MALARIA_HOUSEHOLDITNIRS
# 38                            SA_0000001476
# 39                   SA_0000001476_ARCHIVED
# 40                                SDGAIRBOD
# 41                               SDGAIRBODA
# 42       FINPROTECTION_IMP_BNLFHU_FURIMP_HH
# 43            FINPROTECTION_IMP_BNLFHU_P_HH
# 44   FINPROTECTION_IMP_NP_REL_LEVEL_MILLION
# 45            FINPROTECTION_IMP_NPRELPL_POP
# 46           FINPROTECTION_IMP_PG_RELPL_STD
# 47          FINPROTECTION_IMP_BNLFHU_TOT_HH
# 48        FINPROTECTION_IMP_NP_REL_LEVEL_SH
# 49          FINPROTECTION_CATA_CTPFHU_40_HH
#
#                                         IndicatorName Language
# 0         Household air pollution attributable deaths       EN
# 1   Household air pollution attributable deaths in...       EN
# 2   Household air pollution attributable deaths pe...       EN
# 3   Household air pollution  attributable deaths p...       EN
# 4          Household air pollution attributable DALYs       EN
# 5   Household air pollution attributable DALYs in ...       EN
# 6   Household air pollution attributable DALYs (pe...       EN
# 7   Household air pollution  attributable DALYs pe...       EN
# 8   Household air pollution attributable DALYs (pe...       EN
# 9   Household air pollution attributable death rat...       EN
# 10  Household air pollution attributable death rat...       EN
# 11  Total population with household expenditures o...       EN
# 12  Total population with household expenditures o...       EN
# 13  Population with household expenditures on heal...       EN
# 14  Total population with household expenditures o...       EN
# 15  Total population with household expenditures o...       EN
# 16  Population with household expenditures on heal...       EN
# 17  Total population  pushed below the $1.90 a day...       EN
# 18  Total population  pushed below the $1.90 a day...       EN
# 19  Total population  pushed below the $3.10 a day...       EN
# 20  Total population  pushed below the $3.10 a day...       EN
# 21  Population  pushed below the $1.90 a day  pove...       EN
# 22  Population  pushed below the $3.10 a day  pove...       EN
# 23  Increase in poverty gap  due to household  hea...       EN
# 24  Increase in poverty gap due to household  heal...       EN
# 25  Increase in poverty gap  due to household  hea...       EN
# 26  Increase in poverty gap due to household  heal...       EN
# 27  Data sources used to routinely monitor people ...       EN
# 28         Number of households sprayed at least once       EN
# 29         Number of households targeted for spraying       EN
# 30  Household Net Possession - Percentage with mor...       EN
# 31  Household Net Possession - Average number of n...       EN
# 32  Household Net Possession - Percentage with at ...       EN
# 33  Household Net Possession - Percentage with mor...       EN
# 34  Household Net Possession - Average number of e...       EN
# 35  Household Net Possession - Percentage with mor...       EN
# 36  Household Net Possession - Average number of I...       EN
# 37  Households with at least one insecticide-treat...       EN
# 38  Alcohol expenditure as a per cent of total hou...       EN
# 39  Alcohol expenditure as a per cent of total hou...       EN
# 40  Ambient and household air pollution attributab...       EN
# 41  Ambient and household air pollution attributab...       EN
# 42  Households further impoverished by out-of-pock...       EN
# 43  Households impoverished by out-of-pocket payme...       EN
# 44  Total population pushed below a relative pover...       EN
# 45  Population pushed below a relative poverty lin...       EN
# 46  Increase in poverty gap due to household healt...       EN
# 47  Households pushed below or further below a rel...       EN
# 48  Total population pushed below a relative pover...       EN
# 49  Households with out-of-pocket payments greater...       EN

# %% [markdown]
# # Select only the indicators that have a specific title

# %% [markdown]
# In this example, the indicator `Ambient air pollution attributable deaths` was queried

# %%
# response = urlopen("https://ghoapi.azureedge.net/api/Indicator?$filter=IndicatorName eq 'Ambient air pollution attributable deaths'")
# json_data = response.read().decode('utf-8', 'replace')

# d = json.loads(json_data)
# df_Indicators3 = pd.json_normalize(d['value'])
# df_Indicators3

# %% [markdown]
# # Retrieving indicator data

# %% [markdown]
# Specify an indicator to download by specifying the indicator code. This will return all associated data for that specific indicator.

# %% [markdown]
# ## Case Study : Average life expectancy at birth (in years)

# %% [markdown]
# The indicator code for the ` "Average life expectancy at birth (in years)"` indicator is `WHOSIS_000001`

# %%
response = urlopen("https://ghoapi.azureedge.net/api/WHOSIS_000001")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
df = pd.json_normalize(d['value'])
df.head()
# Out:
#          Id  IndicatorCode SpatialDimType SpatialDim TimeDimType  TimeDim  \
# 0  22847621  WHOSIS_000001        COUNTRY        CAN        YEAR     1920
# 1  24614313  WHOSIS_000001        COUNTRY        AFG        YEAR     2000
# 2  24614317  WHOSIS_000001        COUNTRY        AFG        YEAR     2010
# 3  24614321  WHOSIS_000001        COUNTRY        AFG        YEAR     2015
# 4  24614325  WHOSIS_000001        COUNTRY        AFG        YEAR     2019
#
#   Dim1Type  Dim1 Dim2Type  Dim2  ... DataSourceDim Value NumericValue   Low  \
# 0      SEX  BTSX     None  None  ...          None  82.8     82.80972  None
# 1      SEX   MLE     None  None  ...          None  54.6     54.57449  None
# 2      SEX   MLE     None  None  ...          None  59.6     59.60036  None
# 3      SEX   MLE     None  None  ...          None  61.0     61.03658  None
# 4      SEX   MLE     None  None  ...          None  63.3     63.28709  None
#
#    High                                   Comments  \
# 0  None  WHO life table method: Vital registration
# 1  None                                       None
# 2  None                                       None
# 3  None                                       None
# 4  None                                       None
#
#                             Date TimeDimensionValue  \
# 0   2020-06-04T11:21:09.77+02:00               1920
# 1  2020-12-04T16:59:42.513+01:00               2000
# 2  2020-12-04T16:59:43.013+01:00               2010
# 3  2020-12-04T16:59:43.423+01:00               2015
# 4  2020-12-04T16:59:43.533+01:00               2019
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  1920-01-01T00:00:00+01:00  1920-12-31T00:00:00+01:00
# 1  2000-01-01T00:00:00+01:00  2000-12-31T00:00:00+01:00
# 2  2010-01-01T00:00:00+01:00  2010-12-31T00:00:00+01:00
# 3  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00
# 4  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
#
# [5 rows x 23 columns]

# %%
response = urlopen("https://ghoapi.azureedge.net/api/HRH_30")
json_data = response.read().decode('utf-8', 'replace')

d = json.loads(json_data)
df = pd.json_normalize(d['value'])
df.head()
# Out:
#          Id IndicatorCode SpatialDimType SpatialDim TimeDimType  TimeDim  \
# 0  18016526        HRH_30        COUNTRY        AFG        YEAR     2008
# 1  18016527        HRH_30        COUNTRY        AFG        YEAR     2009
# 2  18016528        HRH_30        COUNTRY        AFG        YEAR     2010
# 3  18016529        HRH_30        COUNTRY        AFG        YEAR     2011
# 4  18016530        HRH_30        COUNTRY        AFG        YEAR     2012
#
#   Dim1Type  Dim1 Dim2Type  Dim2  ... DataSourceDim  Value NumericValue   Low  \
# 0     None  None     None  None  ...          None  0.457        0.457  None
# 1     None  None     None  None  ...          None  0.454        0.454  None
# 2     None  None     None  None  ...          None  0.435        0.435  None
# 3     None  None     None  None  ...          None  0.425        0.425  None
# 4     None  None     None  None  ...          None  0.455        0.455  None
#
#    High  Comments                           Date TimeDimensionValue  \
# 0  None      None      2018-02-26T12:18:42+01:00               2008
# 1  None      None  2018-02-26T12:18:42.023+01:00               2009
# 2  None      None  2018-02-26T12:18:42.043+01:00               2010
# 3  None      None   2018-02-26T12:18:42.06+01:00               2011
# 4  None      None   2018-02-26T12:18:42.08+01:00               2012
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00
# 1  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 2  2010-01-01T00:00:00+01:00  2010-12-31T00:00:00+01:00
# 3  2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00
# 4  2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00
#
# [5 rows x 23 columns]

# %%
df_Code.rename(columns={'Code': 'SpatialDim'}, inplace=True)
df_merged = pd.merge(df, df_Code, how='outer', on='SpatialDim')

# %%
df_merged['Title'] = np.where(df_merged.SpatialDim=="AFR", "Africa", df_merged.Title)
df_merged['ParentTitle'] = np.where(df_merged.SpatialDim=="AFR", "Africa", df_merged.ParentTitle)
df_merged_afro = df_merged[df_merged.ParentTitle=="Africa"][["Title", 'IndicatorCode', 'Dim1', 'TimeDim', 'NumericValue']]
df_merged_afro.head()
# Out:
#      Title  IndicatorCode  Dim1  TimeDim  NumericValue
# 25  Angola  WHOSIS_000001   MLE   2000.0      46.77004
# 26  Angola  WHOSIS_000001   MLE   2010.0      55.77834
# 27  Angola  WHOSIS_000001   MLE   2015.0      59.13242
# 28  Angola  WHOSIS_000001   MLE   2019.0      60.70384
# 29  Angola  WHOSIS_000001  FMLE   2000.0      52.12018

# %%
df_merged_afro.rename(columns={'Title': 'Country', 'IndicatorCode': 'Indicator_Name', 'Dim1': 'Options',
                               'TimeDim': 'Start_Period', 'NumericValue': 'Value_received' }, inplace=True)
df_merged_afro = df_merged_afro.dropna()

# %%
df_merged_afro.Country.unique()
# Out:
# array(['Angola', 'Burundi', 'Benin', 'Burkina Faso', 'Botswana',
#        'Central African Republic', "Côte d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Congo', 'Comoros',
#        'Cabo Verde', 'Algeria', 'Eritrea', 'Ethiopia', 'Gabon', 'Ghana',
#        'Guinea', 'Gambia', 'Guinea-Bissau', 'Equatorial Guinea', 'Kenya',
#        'Liberia', 'Lesotho', 'Madagascar', 'Mali', 'Mozambique',
#        'Mauritania', 'Mauritius', 'Malawi', 'Namibia', 'Niger', 'Nigeria',
#        'Rwanda', 'Senegal', 'Sierra Leone', 'South Sudan',
#        'Sao Tome and Principe', 'Eswatini', 'Seychelles', 'Chad', 'Togo',
#        'United Republic of Tanzania', 'Uganda', 'South Africa', 'Zambia',
#        'Zimbabwe', 'Africa'], dtype=object)

# %%
len(df_merged_afro.Country.unique())
# Out:
# 48

# %%
df_merged_afro.loc[:,'Indicator_Name'] = "Average life expectancy at birth (in years)"
df_merged_afro.loc[:,'Measure_type'] = "Numeric"
df_merged_afro.loc[:,'Source'] = "Global Health Observatory"

# %%
df_merged_afro.head()
# Out:
#    Country                               Indicator_Name Options  Start_Period  \
# 25  Angola  Average life expectancy at birth (in years)     MLE        2000.0
# 26  Angola  Average life expectancy at birth (in years)     MLE        2010.0
# 27  Angola  Average life expectancy at birth (in years)     MLE        2015.0
# 28  Angola  Average life expectancy at birth (in years)     MLE        2019.0
# 29  Angola  Average life expectancy at birth (in years)    FMLE        2000.0
#
#     Value_received Measure_type                     Source
# 25        46.77004      Numeric  Global Health Observatory
# 26        55.77834      Numeric  Global Health Observatory
# 27        59.13242      Numeric  Global Health Observatory
# 28        60.70384      Numeric  Global Health Observatory
# 29        52.12018      Numeric  Global Health Observatory

# %%
df_merged_afro.loc[:,'Options'] = np.where(df_merged_afro.Options=="MLE", "Male",
                                     np.where(df_merged_afro.Options=="FMLE", "Female", "Both sexes"))
df_merged_afro.loc[:,'End_Period'] = df_merged_afro.loc[:,'Start_Period']

# %%
cols = ['Start_Period', 'End_Period']
df_merged_afro[cols] = df_merged_afro[cols].applymap(np.int32)
df_merged_afro = df_merged_afro[["Country", 'Indicator_Name', 'Options', 'Start_Period', 'End_Period',
                                "Value_received", 'Measure_type', 'Source']]
df_merged_afro.head()
# Out:
#    Country                               Indicator_Name Options  Start_Period  \
# 25  Angola  Average life expectancy at birth (in years)    Male          2000
# 26  Angola  Average life expectancy at birth (in years)    Male          2010
# 27  Angola  Average life expectancy at birth (in years)    Male          2015
# 28  Angola  Average life expectancy at birth (in years)    Male          2019
# 29  Angola  Average life expectancy at birth (in years)  Female          2000
#
#     End_Period  Value_received Measure_type                     Source
# 25        2000        46.77004      Numeric  Global Health Observatory
# 26        2010        55.77834      Numeric  Global Health Observatory
# 27        2015        59.13242      Numeric  Global Health Observatory
# 28        2019        60.70384      Numeric  Global Health Observatory
# 29        2000        52.12018      Numeric  Global Health Observatory

# %%
import os

path = r'C:\DownloadTest2'

# Check whether the specified path exists or not
isExist = os.path.exists(path)

if not isExist:
  
  # Create a new directory because it does not exist 
  os.makedirs(path)
  print("The new directory is created!")
# Out:
# The new directory is created!

# %%
fileName = 'Average life expectancy at birth.csv'

df_merged_afro.to_csv (path + '\\' + fileName, index = False, header=True)

# %% [markdown]
# # Function to automate the process

# %%
def IndicatorGHO(IndicatorCode, Indicator_Name, fileName, SourceName):
    response = urlopen("https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues")
    json_data = response.read().decode('utf-8', 'replace')
    d = json.loads(json_data)
    df_Code = pd.json_normalize(d['value'])
    df_Code.rename(columns={'Code': 'SpatialDim'}, inplace=True)
    API = "https://ghoapi.azureedge.net/api/"
    response = urlopen(API + IndicatorCode)
    json_data = response.read().decode('utf-8', 'replace')
    d = json.loads(json_data)
    df = pd.json_normalize(d['value'])
    df_merged = pd.merge(df, df_Code, how='outer', on='SpatialDim')
    
    df_merged['Title'] = np.where((df_merged.SpatialDim=="AFR") | (df_merged.SpatialDim=="WHO_LMI_AFR"), "Africa", df_merged.Title)
    df_merged['ParentTitle'] = np.where((df_merged.SpatialDim=="AFR") | (df_merged.SpatialDim=="WHO_LMI_AFR"), "Africa", df_merged.ParentTitle)
    #df_merged['Title'] = np.where(df_merged.SpatialDim=="AFR", "Africa", df_merged.Title)
    #df_merged['ParentTitle'] = np.where(df_merged.SpatialDim=="AFR", "Africa", df_merged.ParentTitle)
    
    df_merged_afro = df_merged[df_merged.ParentTitle=="Africa"]
    df_merged_afro = df_merged[df_merged.ParentTitle=="Africa"][["Title", 'IndicatorCode', 'Dim1', 'TimeDim', 'NumericValue']]
    df_merged_afro.rename(columns={'Title': 'Country', 'IndicatorCode': 'Indicator_Name', 'Dim1': 'Options',
                               'TimeDim': 'Start_Period', 'NumericValue': 'Value_received' }, inplace=True)
    
    df_merged_afro.drop(df_merged_afro[df_merged_afro.Country.isin(['Saint Helena', 'Mayotte', 'Reunion'])].index, inplace=True)
    #df_merged_afro = df_merged_afro.dropna()
    
    df_merged_afro.loc[:,'Indicator_Name'] = Indicator_Name
    df_merged_afro.loc[:,'Measure_type'] = "Numeric"
    df_merged_afro.loc[:,'Source'] = SourceName
    df_merged_afro.loc[:,'Options'] = np.where(df_merged_afro.Options=="MLE", "Male",
                                           np.where(df_merged_afro.Options=="FMLE", "Female",
                                                    np.where(df_merged_afro.Options=="BTSX", "Both sexes",df_merged_afro.Options)))
    df_merged_afro.loc[:,'Options'] = np.where(df_merged_afro.Options=="URB", "Urban",
                                           np.where(df_merged_afro.Options=="RUR", "Rural",
                                                    np.where(df_merged_afro.Options=="TOTL", "Total",df_merged_afro.Options)))
    df_merged_afro.loc[:,'End_Period'] = df_merged_afro.loc[:,'Start_Period']
    
    #cols = ['Start_Period', 'End_Period']
    #df_merged_afro[cols] = df_merged_afro[cols].applymap(np.int32)
    #df_merged_afro
    
    df_merged_afro = df_merged_afro[["Country", 'Indicator_Name', 'Options', 'Start_Period', 'End_Period',
                                "Value_received", 'Measure_type', 'Source']]
    path = r'D:\DownloadTest2'

    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    
    if not isExist:
        # Create a new directory because it does not exist 
        os.makedirs(path)
    df_merged_afro.to_csv (path + '\\' + fileName + '.csv', index = False, header=True)

# %%
IndicatorGHO("WHOSIS_000002", "Healthy life expectancy (HALE) at birth", "Healthy life expectancy", "Global Health Observatory")

# %%
IndicatorGHO("WHOSIS_000015", "Life expectancy at age 60 (years)", "Life expectancy at age 60", "Global Health Observatory")

# %% [markdown]
# # Loop through all the indicators

# %%
ListOfIndicators = pd.read_csv(r'D:\PERSONNEL\OMS\TRAVAIL\Indicateur\IndicatorsCodeGHO.csv', encoding='iso-8859-1')
ListOfIndicators.head()
# Out:
#   IndicatorCodeGHO                                          Indicator  \
# 0    WHOSIS_000001        Average life expectancy at birth (in years)
# 1    WHOSIS_000002            Healthy life expectancy (HALE) at birth
# 2    WHOSIS_000015                  Life expectancy at age 60 (years)
# 3          MORTADO  Adolescent mortality rate (per 100 000 adolesc...
# 4    WHOSIS_000004  Adult mortality rate (probably of dying betwee...
#
#   FileName                     Source
# 0    file1  Global Health Observatory
# 1    file2  Global Health Observatory
# 2    file3  Global Health Observatory
# 3    file4  Global Health Observatory
# 4    file5  Global Health Observatory

# %%
for index, row in ListOfIndicators.iterrows():
    try:
        IndicatorGHO(row['IndicatorCodeGHO'], row['Indicator'], row['FileName'], row['Source'])
        print(f"The indicator number {index+1} is processed, please go and check to D:\DownloadTest2")
    except ValueError:
        print(f"The indicator number {index+1} is not processed because of error")
# Out:
# The indicator number 1 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 2 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 3 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 4 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 5 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 6 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 7 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 8 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 9 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 10 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 11 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 12 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 13 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 14 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 15 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 16 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 17 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 18 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 19 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 20 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 21 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 22 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 23 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 24 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 25 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 26 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 27 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 28 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 29 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 30 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 31 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 32 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 33 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 34 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 35 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 36 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 37 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 38 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 39 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 40 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 41 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 42 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 43 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 44 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 45 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 46 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 47 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 48 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 49 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 50 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 51 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 52 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 53 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 54 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 55 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 56 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 57 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 58 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 59 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 60 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 61 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 62 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 63 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 64 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 65 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 66 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 67 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 68 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 69 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 70 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 71 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 72 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 73 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 74 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 75 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 76 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 77 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 78 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 79 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 80 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 81 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 82 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 83 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 84 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 85 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 86 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 87 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 88 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 89 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 90 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 91 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 92 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 93 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 94 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 95 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 96 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 97 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 98 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 99 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 100 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 101 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 102 is processed, please go and check to D:\DownloadTest2
# Well done!
# The indicator number 103 is processed, please go and check to D:\DownloadTest2
# Well done!
